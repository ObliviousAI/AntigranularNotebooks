# %% [markdown]
# # 📊 **Antigranular** Heart Disease Prediction Contest (ft. **Harvard/OpenDP** and **TPDP**)
#
# I want to start my notebook by acknowledging that I used epsilon of 1 when calling the standard scaler. Other parts are pretty similar to the 1st Trial Notebook. Initially, I did not know that each participant only has 10 epsilon in total for this competition. For anyone in the future, be mindful with calling the functions including epsilon as their parameters.

# %% [markdown]
# ### 📦 Install Antigranular
#
# This command installs the [Antigranular PyPI Package](https://pypi.org/project/antigranular/) on the local enviroment.

# %%
# Install the Antigranular package
# !pip install antigranular &> /dev/null

# %% [markdown]
# ### ✍ Login to the Enclave
#
# Head over to [Competitions](https://www.antigranular.com/competitions) to find your `<user_id>`, `<user_secret>` and the competition's name and copy that command here.
#
# ![img](https://docs.antigranular.com/shots/comp_cell.png)

# %%
import antigranular as ag
session = ag.login(<client_id>,<client_secret>, competition = "Heart Disease Prediction Hackathon")
# Out:
# Dataset "Heart Disease Prediction Hackathon Dataset" loaded to the kernel as heart_disease_prediction_hackathon_dataset
# Key Name                       Value Type
# ---------------------------------------------
# train_y                        PrivateDataFrame
# train_x                        PrivateDataFrame
# test_x                         DataFrame
#
# Connected to Antigranular server session id: 254a5103-244e-41d5-8a9d-88bbc758bb43, the session will time out if idle for 25 minutes
# Cell magic '%%ag' registered successfully, use `%%ag` in a notebook cell to execute your python code on Antigranular private python server
# 🚀 Everything's set up and ready to roll!

# %% [markdown]
# ### 🤖 Using AG
#
# You can now simply use ``%%ag`` to run code on an enclave! You can always head over to our [Docs](https://docs.antigranular.com/) to learn more about AG, but for now, we can define train and test variables as follows.

# %%
# %%ag
# x_train = heart_disease_prediction_hackathon_dataset["train_x"]
# y_train = heart_disease_prediction_hackathon_dataset["train_y"]
# x_test = heart_disease_prediction_hackathon_dataset["test_x"]

# %% [markdown]
# ### 🕵️‍♂️ Exploring data
#
# Exploring data in Antigranular involves spending your epsilon budget, be mindful of your usage but remember that the less epsilon you use, the less accurate your results will get!

# %%
# %%ag
# x_train.info()
# Out:
# +----+----------+-------------+---------------+---------+------------+
# |    | Column   | numerical   | categorical   | dtype   | bounds     |
# |----+----------+-------------+---------------+---------+------------|
# |  0 | age      | True        | False         | int64   | (21, 86)   |
# |  1 | sex      | True        | False         | int64   | (0, 1)     |
# |  2 | bp       | True        | False         | int64   | (80, 215)  |
# |  3 | ch       | True        | False         | int64   | (102, 597) |
# |  4 | bs       | True        | False         | int64   | (67, 157)  |
# |  5 | phr      | True        | False         | int64   | (62, 222)  |
# +----+----------+-------------+---------------+---------+------------+

# %% [markdown]
# ### 🎈 Import packages
#
# Please make sure to read [Antigranular DOCS](https://docs.antigranular.com/) for all the packages and functions that you are importing.

# %%
# %%ag
# import tensorflow as tf
# from op_pandas import standard_scaler, PrivateDataFrame
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout
# from op_tensorflow import PrivateKerasModel, PrivateDataLoader
# Out:
# /usr/local/lib/python3.10/site-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if (distutils.version.LooseVersion(tf.__version__) <
# /usr/local/lib/python3.10/site-packages/tensorflow_probability/python/__init__.py:58: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   distutils.version.LooseVersion(required_tensorflow_version)):

# %% [markdown]
# ### 🎈 A simply solution
#
# The model itself is slightly different from the model in 1st Trial Notebook. I simply increased the number of nodes in the neural networks and decreased the dropout ratio.

# %%
# %%ag
# # Normal keras model
# seqM = Sequential([
#     Dense(128, activation='relu', input_shape=(6,)),
#     Dropout(0.2),
#     Dense(128, activation='relu'),
#     Dense(1, activation='sigmoid')  # Binary classification
# ])
#
# # Create DP keras model
# dp_model = PrivateKerasModel(model=seqM, l2_norm_clip=1, noise_multiplier=1)
#
# # Use a standard (non-DP) optimizer directly from keras.
# optimizer = tf.keras.optimizers.Adam(learning_rate=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-7)
#
# # PrivateKerasModel uses similar API as standard Keras
# dp_model.compile(
# 	optimizer = optimizer,
# 	loss = 'binary_crossentropy',
# 	metrics = ["accuracy"]
# )

# %% [markdown]
# ***Warning***
#
# Make sure not to call the standard_scaler function with high epsilon value! This will cap out your total epsilon very quickly. Test with small epsilon value all the time. Also

# %%
# %%ag
# x_train_scaled = standard_scaler(x_train, eps=1)
# x_test_scaler = standard_scaler(PrivateDataFrame(x_test), eps=1)

# %% [markdown]
# In order to train your data in the model, you need to load it using the PrivateDataLoader function.

# %%
# %%ag
# data_loader = PrivateDataLoader(feature_df=x_train_scaled , label_df=y_train, batch_size=64)

# %% [markdown]
# ### 🎈 Training
#
# Before training, review [Tensorflow Privacy](https://docs.antigranular.com/private-python/packages/tensorflow) and calculate the epsilon required, since fit function can use a lot of your precious epsilon.

# %%
# %%ag
# dp_model.fit(x=data_loader, epochs=100, target_delta=1e-5)
# Out:
# Epoch 1/100
#
# 125/125 - 5s - loss: 0.4794 - accuracy: 0.7562 - 5s/epoch - 43ms/step
#
# Epoch 2/100
#
# 125/125 - 2s - loss: 0.3815 - accuracy: 0.8151 - 2s/epoch - 18ms/step
#
# Epoch 3/100
#
# 125/125 - 2s - loss: 0.3250 - accuracy: 0.8469 - 2s/epoch - 19ms/step
#
# Epoch 4/100
#
# 125/125 - 2s - loss: 0.2713 - accuracy: 0.8829 - 2s/epoch - 18ms/step
#
# Epoch 5/100
#
# 125/125 - 2s - loss: 0.2314 - accuracy: 0.8956 - 2s/epoch - 18ms/step
#
# Epoch 6/100
#
# 125/125 - 2s - loss: 0.1960 - accuracy: 0.9185 - 2s/epoch - 18ms/step
#
# Epoch 7/100
#
# 125/125 - 2s - loss: 0.1942 - accuracy: 0.9188 - 2s/epoch - 18ms/step
#
# Epoch 8/100
#
# 125/125 - 2s - loss: 0.1793 - accuracy: 0.9267 - 2s/epoch - 18ms/step
#
# Epoch 9/100
#
# 125/125 - 2s - loss: 0.1641 - accuracy: 0.9335 - 2s/epoch - 18ms/step
#
# Epoch 10/100
#
# 125/125 - 2s - loss: 0.1487 - accuracy: 0.9440 - 2s/epoch - 18ms/step
#
# Epoch 11/100
#
# 125/125 - 2s - loss: 0.1452 - accuracy: 0.9406 - 2s/epoch - 18ms/step
#
# Epoch 12/100
#
# 125/125 - 2s - loss: 0.1283 - accuracy: 0.9502 - 2s/epoch - 18ms/step
#
# Epoch 13/100
#
# 125/125 - 2s - loss: 0.1303 - accuracy: 0.9496 - 2s/epoch - 17ms/step
#
# Epoch 14/100
#
# 125/125 - 2s - loss: 0.1251 - accuracy: 0.9512 - 2s/epoch - 18ms/step
#
# Epoch 15/100
#
# 125/125 - 2s - loss: 0.1254 - accuracy: 0.9511 - 2s/epoch - 18ms/step
#
# Epoch 16/100
#
# 125/125 - 2s - loss: 0.1158 - accuracy: 0.9551 - 2s/epoch - 19ms/step
#
# Epoch 17/100
#
# 125/125 - 2s - loss: 0.1347 - accuracy: 0.9489 - 2s/epoch - 18ms/step
#
# Epoch 18/100
#
# 125/125 - 2s - loss: 0.1100 - accuracy: 0.9561 - 2s/epoch - 18ms/step
#
# Epoch 19/100
#
# 125/125 - 2s - loss: 0.1125 - accuracy: 0.9553 - 2s/epoch - 18ms/step
#
# Epoch 20/100
#
# 125/125 - 2s - loss: 0.1080 - accuracy: 0.9604 - 2s/epoch - 17ms/step
#
# Epoch 21/100
#
# 125/125 - 2s - loss: 0.0985 - accuracy: 0.9622 - 2s/epoch - 18ms/step
#
# Epoch 22/100
#
# 125/125 - 2s - loss: 0.1024 - accuracy: 0.9617 - 2s/epoch - 18ms/step
#
# Epoch 23/100
#
# 125/125 - 2s - loss: 0.0985 - accuracy: 0.9626 - 2s/epoch - 18ms/step
#
# Epoch 24/100
#
# 125/125 - 2s - loss: 0.0906 - accuracy: 0.9661 - 2s/epoch - 18ms/step
#
# Epoch 25/100
#
# 125/125 - 2s - loss: 0.0971 - accuracy: 0.9613 - 2s/epoch - 18ms/step
#
# Epoch 26/100
#
# 125/125 - 2s - loss: 0.0911 - accuracy: 0.9627 - 2s/epoch - 18ms/step
#
# Epoch 27/100
#
# 125/125 - 2s - loss: 0.0944 - accuracy: 0.9646 - 2s/epoch - 18ms/step
#
# Epoch 28/100
#
# 125/125 - 2s - loss: 0.0878 - accuracy: 0.9653 - 2s/epoch - 18ms/step
#
# Epoch 29/100
#
# 125/125 - 2s - loss: 0.1055 - accuracy: 0.9633 - 2s/epoch - 18ms/step
#
# Epoch 30/100
#
# 125/125 - 2s - loss: 0.0956 - accuracy: 0.9623 - 2s/epoch - 18ms/step
#
# Epoch 31/100
#
# 125/125 - 2s - loss: 0.0922 - accuracy: 0.9651 - 2s/epoch - 18ms/step
#
# Epoch 32/100
#
# 125/125 - 2s - loss: 0.0790 - accuracy: 0.9702 - 2s/epoch - 18ms/step
#
# Epoch 33/100
#
# 125/125 - 2s - loss: 0.0836 - accuracy: 0.9685 - 2s/epoch - 18ms/step
#
# Epoch 34/100
#
# 125/125 - 2s - loss: 0.0842 - accuracy: 0.9683 - 2s/epoch - 18ms/step
#
# Epoch 35/100
#
# 125/125 - 2s - loss: 0.0791 - accuracy: 0.9698 - 2s/epoch - 18ms/step
#
# Epoch 36/100
#
# 125/125 - 2s - loss: 0.0811 - accuracy: 0.9688 - 2s/epoch - 18ms/step
#
# Epoch 37/100
#
# 125/125 - 2s - loss: 0.0778 - accuracy: 0.9712 - 2s/epoch - 18ms/step
#
# Epoch 38/100
#
# 125/125 - 2s - loss: 0.1019 - accuracy: 0.9639 - 2s/epoch - 18ms/step
#
# Epoch 39/100
#
# 125/125 - 2s - loss: 0.0748 - accuracy: 0.9717 - 2s/epoch - 18ms/step
#
# Epoch 40/100
#
# 125/125 - 2s - loss: 0.0748 - accuracy: 0.9711 - 2s/epoch - 18ms/step
#
# Epoch 41/100
#
# 125/125 - 2s - loss: 0.0652 - accuracy: 0.9734 - 2s/epoch - 18ms/step
#
# Epoch 42/100
#
# 125/125 - 2s - loss: 0.0843 - accuracy: 0.9687 - 2s/epoch - 19ms/step
#
# Epoch 43/100
#
# 125/125 - 2s - loss: 0.0798 - accuracy: 0.9694 - 2s/epoch - 19ms/step
#
# Epoch 44/100
#
# 125/125 - 2s - loss: 0.0786 - accuracy: 0.9711 - 2s/epoch - 19ms/step
#
# Epoch 45/100
#
# 125/125 - 2s - loss: 0.0718 - accuracy: 0.9739 - 2s/epoch - 18ms/step
#
# Epoch 46/100
#
# 125/125 - 2s - loss: 0.0751 - accuracy: 0.9731 - 2s/epoch - 18ms/step
#
# Epoch 47/100
#
# 125/125 - 2s - loss: 0.0625 - accuracy: 0.9758 - 2s/epoch - 18ms/step
#
# Epoch 48/100
#
# 125/125 - 2s - loss: 0.0689 - accuracy: 0.9744 - 2s/epoch - 18ms/step
#
# Epoch 49/100
#
# 125/125 - 2s - loss: 0.0627 - accuracy: 0.9764 - 2s/epoch - 18ms/step
#
# Epoch 50/100
#
# 125/125 - 2s - loss: 0.0683 - accuracy: 0.9764 - 2s/epoch - 18ms/step
#
# Epoch 51/100
#
# 125/125 - 2s - loss: 0.0618 - accuracy: 0.9769 - 2s/epoch - 18ms/step
#
# Epoch 52/100
#
# 125/125 - 2s - loss: 0.0694 - accuracy: 0.9751 - 2s/epoch - 18ms/step
#
# Epoch 53/100
#
# 125/125 - 2s - loss: 0.0795 - accuracy: 0.9712 - 2s/epoch - 18ms/step
#
# Epoch 54/100
#
# 125/125 - 2s - loss: 0.0774 - accuracy: 0.9734 - 2s/epoch - 18ms/step
#
# Epoch 55/100
#
# 125/125 - 2s - loss: 0.0648 - accuracy: 0.9745 - 2s/epoch - 18ms/step
#
# Epoch 56/100
#
# 125/125 - 2s - loss: 0.0702 - accuracy: 0.9746 - 2s/epoch - 18ms/step
#
# Epoch 57/100
#
# 125/125 - 2s - loss: 0.0665 - accuracy: 0.9762 - 2s/epoch - 18ms/step
#
# Epoch 58/100
#
# 125/125 - 2s - loss: 0.0500 - accuracy: 0.9807 - 2s/epoch - 18ms/step
#
# Epoch 59/100
#
# 125/125 - 2s - loss: 0.0621 - accuracy: 0.9778 - 2s/epoch - 18ms/step
#
# Epoch 60/100
#
# 125/125 - 2s - loss: 0.0674 - accuracy: 0.9773 - 2s/epoch - 18ms/step
#
# Epoch 61/100
#
# 125/125 - 2s - loss: 0.0686 - accuracy: 0.9747 - 2s/epoch - 18ms/step
#
# Epoch 62/100
#
# 125/125 - 2s - loss: 0.0643 - accuracy: 0.9765 - 2s/epoch - 18ms/step
#
# Epoch 63/100
#
# 125/125 - 2s - loss: 0.0783 - accuracy: 0.9742 - 2s/epoch - 18ms/step
#
# Epoch 64/100
#
# 125/125 - 2s - loss: 0.0570 - accuracy: 0.9789 - 2s/epoch - 18ms/step
#
# Epoch 65/100
#
# 125/125 - 2s - loss: 0.0569 - accuracy: 0.9797 - 2s/epoch - 18ms/step
#
# Epoch 66/100
#
# 125/125 - 2s - loss: 0.0675 - accuracy: 0.9758 - 2s/epoch - 18ms/step
#
# Epoch 67/100
#
# 125/125 - 2s - loss: 0.0668 - accuracy: 0.9774 - 2s/epoch - 18ms/step
#
# Epoch 68/100
#
# 125/125 - 2s - loss: 0.0591 - accuracy: 0.9784 - 2s/epoch - 18ms/step
#
# Epoch 69/100
#
# 125/125 - 2s - loss: 0.0622 - accuracy: 0.9775 - 2s/epoch - 18ms/step
#
# Epoch 70/100
#
# 125/125 - 2s - loss: 0.0546 - accuracy: 0.9801 - 2s/epoch - 17ms/step
#
# Epoch 71/100
#
# 125/125 - 2s - loss: 0.0612 - accuracy: 0.9774 - 2s/epoch - 18ms/step
#
# Epoch 72/100
#
# 125/125 - 2s - loss: 0.0682 - accuracy: 0.9758 - 2s/epoch - 18ms/step
#
# Epoch 73/100
#
# 125/125 - 2s - loss: 0.0782 - accuracy: 0.9723 - 2s/epoch - 18ms/step
#
# Epoch 74/100
#
# 125/125 - 2s - loss: 0.0535 - accuracy: 0.9816 - 2s/epoch - 18ms/step
#
# Epoch 75/100
#
# 125/125 - 2s - loss: 0.0491 - accuracy: 0.9835 - 2s/epoch - 18ms/step
#
# Epoch 76/100
#
# 125/125 - 2s - loss: 0.0622 - accuracy: 0.9795 - 2s/epoch - 18ms/step
#
# Epoch 77/100
#
# 125/125 - 2s - loss: 0.0669 - accuracy: 0.9778 - 2s/epoch - 18ms/step
#
# Epoch 78/100
#
# 125/125 - 2s - loss: 0.0531 - accuracy: 0.9816 - 2s/epoch - 18ms/step
#
# Epoch 79/100
#
# 125/125 - 2s - loss: 0.0607 - accuracy: 0.9785 - 2s/epoch - 18ms/step
#
# Epoch 80/100
#
# 125/125 - 2s - loss: 0.0543 - accuracy: 0.9811 - 2s/epoch - 19ms/step
#
# Epoch 81/100
#
# 125/125 - 2s - loss: 0.0584 - accuracy: 0.9791 - 2s/epoch - 18ms/step
#
# Epoch 82/100
#
# 125/125 - 2s - loss: 0.0633 - accuracy: 0.9791 - 2s/epoch - 18ms/step
#
# Epoch 83/100
#
# 125/125 - 2s - loss: 0.0696 - accuracy: 0.9757 - 2s/epoch - 18ms/step
#
# Epoch 84/100
#
# 125/125 - 2s - loss: 0.0524 - accuracy: 0.9810 - 2s/epoch - 18ms/step
#
# Epoch 85/100
#
# 125/125 - 2s - loss: 0.0538 - accuracy: 0.9805 - 2s/epoch - 18ms/step
#
# Epoch 86/100
#
# 125/125 - 2s - loss: 0.0591 - accuracy: 0.9797 - 2s/epoch - 18ms/step
#
# Epoch 87/100
#
# 125/125 - 2s - loss: 0.0576 - accuracy: 0.9792 - 2s/epoch - 18ms/step
#
# Epoch 88/100
#
# 125/125 - 2s - loss: 0.0488 - accuracy: 0.9833 - 2s/epoch - 19ms/step
#
# Epoch 89/100
#
# 125/125 - 2s - loss: 0.0614 - accuracy: 0.9780 - 2s/epoch - 18ms/step
#
# Epoch 90/100
#
# 125/125 - 2s - loss: 0.0459 - accuracy: 0.9836 - 2s/epoch - 18ms/step
#
# Epoch 91/100
#
# 125/125 - 2s - loss: 0.0466 - accuracy: 0.9844 - 2s/epoch - 18ms/step
#
# Epoch 92/100
#
# 125/125 - 2s - loss: 0.0559 - accuracy: 0.9824 - 2s/epoch - 18ms/step
#
# Epoch 93/100
#
# 125/125 - 2s - loss: 0.0670 - accuracy: 0.9767 - 2s/epoch - 18ms/step
#
# Epoch 94/100
#
# 125/125 - 2s - loss: 0.0620 - accuracy: 0.9758 - 2s/epoch - 18ms/step
#
# Epoch 95/100
#
# 125/125 - 2s - loss: 0.0586 - accuracy: 0.9783 - 2s/epoch - 19ms/step
#
# Epoch 96/100
#
# 125/125 - 2s - loss: 0.0660 - accuracy: 0.9791 - 2s/epoch - 19ms/step
#
# Epoch 97/100
#
# 125/125 - 2s - loss: 0.0558 - accuracy: 0.9797 - 2s/epoch - 19ms/step
#
# Epoch 98/100
#
# 125/125 - 2s - loss: 0.0572 - accuracy: 0.9798 - 2s/epoch - 18ms/step
#
# Epoch 99/100
#
# 125/125 - 2s - loss: 0.0624 - accuracy: 0.9787 - 2s/epoch - 18ms/step
#
# Epoch 100/100
#
# 125/125 - 2s - loss: 0.0479 - accuracy: 0.9813 - 2s/epoch - 18ms/step
#
# message: Error ID is - ceb0692b-46ef-4063-8ac9-fe39cfe6029e - Error from upstream service: Client error '400 Bad Request' for url 'http://supervisor-prod-private.antigranular.com/privacyRequest'
# For more information check: https://httpstatuses.com/400. Response text: {"detail":"Maximum delta or epsilon exceeded per query. Per query limits are eps : 1 and delta : 1"}
#
# message: Error ID is - 80c32d84-3412-4ee3-bd76-994c3db7f5bd - Error from upstream service: Client error '400 Bad Request' for url 'http://supervisor-prod-private.antigranular.com/privacyRequest'
# For more information check: https://httpstatuses.com/400. Response text: {"detail":"Maximum delta or epsilon exceeded per query. Per query limits are eps : 1 and delta : 1"}
#
# ValueError: Request Limit Exceeded!

# %% [markdown]
# If you scaled your training data, make sure to scale your test data before you predict.

# %%
# %%ag
# y_pred = dp_model.predict(x_test_scaler, label_columns=["output"])
# Out:
#  1/63 [..............................] - ETA: 18s
#  2/63 [..............................] - ETA: 4s
# 17/63 [=======>......................] - ETA: 0s
# 34/63 [===============>..............] - ETA: 0s
# 52/63 [=======================>......] - ETA: 0s
# 63/63 [==============================] - 1s 6ms/step

# %% [markdown]
# If you have 2 nodes in the last layer except 1 in your neural network, then you do not need to do this, but since I have only 1 node in the last layer, I need to divide my prediction into either 1 or 0.

# %%
# %%ag
# def f(x: float) -> float:
#   if x > 0.5:
#     return 1
#   else:
#     return 0
#
# y_pred["output"] = y_pred["output"].map(f, output_bounds=(0, 1))

# %% [markdown]
# ### 📝 Make your submission (Through AG)
#
# Submit a prediction by simply typing `submit_predictions(your_prediction)` to find out how you rank on the leaderboard.
#
# ![img](https://www.antigranular.com/static/media/Step%209.8091828f3cff4324fe6d.png)

# %%
# %%ag
# result = submit_predictions(y_pred)
# Out:
# score: {'leaderboard': 0.8425859130351336, 'logs': {'BIN_ACC': 0.8545321030863583, 'LIN_EPS': -0.011946190051224609}}

# %% [markdown]
# ### Improvement
#
# 1. Based on Omer Yentur's [solution](https://www.antigranular.com/notebooks/66a1f94c019ee6315e603829), Omer used own scaler instead of the standard_scaler function. Using standard_scaler function introduces randomness based on the value of epsilon (the lower epsilon value gives more randomness). Hence, implementing your own scaler will increase the performance dramatically as Omer Yentur did.
# 2. The cutoff for predictions was 0.5 for this notebook. There may be better cutoff value than 0.5.
# 3. More layers will result in better performance, as Mosbeh Barhoumi's [solution](https://www.antigranular.com/notebooks/66a2118a019ee6315e62023e) and Ala Ammari's [solution](https://www.antigranular.com/notebooks/66a21447019ee6315e6239ce) show. They both used epsilon value of 0.9, lower than mine, and used neural network with more layers.
